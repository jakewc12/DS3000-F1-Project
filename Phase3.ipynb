# %%
#import necessary libraries 
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
import warnings
warnings.simplefilter("ignore")
pd.set_option('display.max_columns', None)
# Out:
# /Users/matthewchang/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/matthewchang/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /var/folders/sr/w85bjnh52gdb6w8z8qm2mfl40000gn/T/ipykernel_23763/4114730977.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# /Users/matthewchang/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#import necessary dataframe and merge 
result_df = pd.read_csv('results.csv')
stats_df = pd.read_csv('status.csv')
drivers_df = pd.read_csv('drivers.csv')
races_df = pd.read_csv('races.csv')
constructor_df = pd.read_csv('constructors.csv')
driver_standings_df = pd.read_csv('driver_standings.csv')

# %%
stats_df
# Out:
#      statusId          status
# 0           1        Finished
# 1           2    Disqualified
# 2           3        Accident
# 3           4       Collision
# 4           5          Engine
# ..        ...             ...
# 134       137          Damage
# 135       138          Debris
# 136       139         Illness
# 137       140       Undertray
# 138       141  Cooling system
#
# [139 rows x 2 columns]

# %%
# merging all seperate dataframe into single dataframe as df

con1 = pd.merge(result_df, races_df, on ='raceId')
con2 = pd.merge(con1, drivers_df, on = 'driverId')
con3 = pd.merge(con2, driver_standings_df, on = 'driverId')
con4 = pd.merge(con3, constructor_df, on ='constructorId')
df = pd.merge(con4, stats_df, on ='statusId')
pd.get_option("display.max_columns",None)

# %%
result_df.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# 1         41    3       1:27.739         217.586         1
# 2         41    5       1:28.090         216.719         1
# 3         58    7       1:28.603         215.464         1
# 4         43    1       1:27.418         218.385         1

# %%
df.head()
# Out:
#    resultId  raceId_x  driverId  constructorId number_x  grid position_x  \
# 0         1        18         1              1       22     1          1
# 1         1        18         1              1       22     1          1
# 2         1        18         1              1       22     1          1
# 3         1        18         1              1       22     1          1
# 4         1        18         1              1       22     1          1
#
#   positionText_x  positionOrder  points_x  laps       time_x milliseconds  \
# 0              1              1      10.0    58  1:34:50.616      5690616
# 1              1              1      10.0    58  1:34:50.616      5690616
# 2              1              1      10.0    58  1:34:50.616      5690616
# 3              1              1      10.0    58  1:34:50.616      5690616
# 4              1              1      10.0    58  1:34:50.616      5690616
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId  year  round  \
# 0         39    2       1:27.452         218.300         1  2008      1
# 1         39    2       1:27.452         218.300         1  2008      1
# 2         39    2       1:27.452         218.300         1  2008      1
# 3         39    2       1:27.452         218.300         1  2008      1
# 4         39    2       1:27.452         218.300         1  2008      1
#
#    circuitId                 name_x        date    time_y  \
# 0          1  Australian Grand Prix  2008-03-16  04:30:00
# 1          1  Australian Grand Prix  2008-03-16  04:30:00
# 2          1  Australian Grand Prix  2008-03-16  04:30:00
# 3          1  Australian Grand Prix  2008-03-16  04:30:00
# 4          1  Australian Grand Prix  2008-03-16  04:30:00
#
#                                                url_x fp1_date fp1_time  \
# 0  http://en.wikipedia.org/wiki/2008_Australian_G...       \N       \N
# 1  http://en.wikipedia.org/wiki/2008_Australian_G...       \N       \N
# 2  http://en.wikipedia.org/wiki/2008_Australian_G...       \N       \N
# 3  http://en.wikipedia.org/wiki/2008_Australian_G...       \N       \N
# 4  http://en.wikipedia.org/wiki/2008_Australian_G...       \N       \N
#
#   fp2_date fp2_time fp3_date fp3_time quali_date quali_time sprint_date  \
# 0       \N       \N       \N       \N         \N         \N          \N
# 1       \N       \N       \N       \N         \N         \N          \N
# 2       \N       \N       \N       \N         \N         \N          \N
# 3       \N       \N       \N       \N         \N         \N          \N
# 4       \N       \N       \N       \N         \N         \N          \N
#
#   sprint_time driverRef number_y code forename   surname         dob  \
# 0          \N  hamilton       44  HAM    Lewis  Hamilton  1985-01-07
# 1          \N  hamilton       44  HAM    Lewis  Hamilton  1985-01-07
# 2          \N  hamilton       44  HAM    Lewis  Hamilton  1985-01-07
# 3          \N  hamilton       44  HAM    Lewis  Hamilton  1985-01-07
# 4          \N  hamilton       44  HAM    Lewis  Hamilton  1985-01-07
#
#   nationality_x                                        url_y  \
# 0       British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1       British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2       British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 3       British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 4       British  http://en.wikipedia.org/wiki/Lewis_Hamilton
#
#    driverStandingsId  raceId_y  points_y  position_y positionText_y  wins  \
# 0                  1        18      10.0           1              1     1
# 1                  9        19      14.0           1              1     1
# 2                 27        20      14.0           3              3     1
# 3                 48        21      20.0           2              2     1
# 4                 69        22      28.0           3              3     1
#
#   constructorRef   name_y nationality_y                                   url  \
# 0        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 1        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 2        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 3        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 4        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
#
#      status
# 0  Finished
# 1  Finished
# 2  Finished
# 3  Finished
# 4  Finished

# %%
df.describe().T
# Out:
#                        count          mean           std     min      25%  \
# resultId           3537627.0  12630.091396   8209.508032     1.0   5125.0
# raceId_x           3537627.0    517.066570    331.536193     1.0    234.0
# driverId           3537627.0    204.182795    265.852299     1.0     20.0
# constructorId      3537627.0     39.412151     56.860468     1.0      6.0
# grid               3537627.0      9.763203      6.557031     0.0      4.0
# positionOrder      3537627.0     11.229562      7.378775     1.0      5.0
# points_x           3537627.0      2.998598      5.334331     0.0      0.0
# laps               3537627.0     48.362040     25.123229     0.0     32.0
# statusId           3537627.0     13.238133     22.544512     1.0      1.0
# year               3537627.0   1996.431836     17.335956  1950.0   1984.0
# round              3537627.0      8.862904      5.106326     1.0      5.0
# circuitId          3537627.0     22.073482     18.755852     1.0      9.0
# driverStandingsId  3537627.0  40117.463301  25309.272186     1.0  13856.0
# raceId_y           3537627.0    519.330155    331.962602     1.0    238.0
# points_y           3537627.0     28.391002     52.047553     0.0      1.0
# position_y         3537627.0     11.654836      9.133026     1.0      5.0
# wins               3537627.0      0.551738      1.452231     0.0      0.0
#
#                        50%      75%      max
# resultId           11763.0  21140.0  26085.0
# raceId_x             467.0    856.0   1110.0
# driverId             105.0    229.0    858.0
# constructorId         16.0     37.0    214.0
# grid                   9.0     15.0     34.0
# positionOrder         10.0     17.0     39.0
# points_x               0.0      4.0     50.0
# laps                  55.0     67.0    200.0
# statusId               5.0     12.0    141.0
# year                1998.0   2011.0   2023.0
# round                  9.0     13.0     22.0
# circuitId             15.0     30.0     79.0
# driverStandingsId  49960.0  65824.0  72187.0
# raceId_y             470.0    857.0   1110.0
# points_y               8.0     31.0    454.0
# position_y            10.0     16.0    108.0
# wins                   0.0      0.0     15.0

# %%
col_name = {'number_x':'number','milliseconds':'timetaken_in_millisec','fastestLapSpeed':'max_speed',
 'name_x':'grand_prix','number_y':'driver_num','code':'driver_code','nationality_x':'nationality','name_y':'company',
 'raceId_x':'racerId','points_x':'points','position_y':'position'}

df.rename(columns=col_name,inplace=True)
df.head()
# Out:
#    resultId  racerId  driverId  constructorId number  grid position_x  \
# 0         1       18         1              1     22     1          1
# 1         1       18         1              1     22     1          1
# 2         1       18         1              1     22     1          1
# 3         1       18         1              1     22     1          1
# 4         1       18         1              1     22     1          1
#
#   positionText_x  positionOrder  points  laps       time_x  \
# 0              1              1    10.0    58  1:34:50.616
# 1              1              1    10.0    58  1:34:50.616
# 2              1              1    10.0    58  1:34:50.616
# 3              1              1    10.0    58  1:34:50.616
# 4              1              1    10.0    58  1:34:50.616
#
#   timetaken_in_millisec fastestLap rank fastestLapTime max_speed  statusId  \
# 0               5690616         39    2       1:27.452   218.300         1
# 1               5690616         39    2       1:27.452   218.300         1
# 2               5690616         39    2       1:27.452   218.300         1
# 3               5690616         39    2       1:27.452   218.300         1
# 4               5690616         39    2       1:27.452   218.300         1
#
#    year  round  circuitId             grand_prix        date    time_y  \
# 0  2008      1          1  Australian Grand Prix  2008-03-16  04:30:00
# 1  2008      1          1  Australian Grand Prix  2008-03-16  04:30:00
# 2  2008      1          1  Australian Grand Prix  2008-03-16  04:30:00
# 3  2008      1          1  Australian Grand Prix  2008-03-16  04:30:00
# 4  2008      1          1  Australian Grand Prix  2008-03-16  04:30:00
#
#                                                url_x fp1_date fp1_time  \
# 0  http://en.wikipedia.org/wiki/2008_Australian_G...       \N       \N
# 1  http://en.wikipedia.org/wiki/2008_Australian_G...       \N       \N
# 2  http://en.wikipedia.org/wiki/2008_Australian_G...       \N       \N
# 3  http://en.wikipedia.org/wiki/2008_Australian_G...       \N       \N
# 4  http://en.wikipedia.org/wiki/2008_Australian_G...       \N       \N
#
#   fp2_date fp2_time fp3_date fp3_time quali_date quali_time sprint_date  \
# 0       \N       \N       \N       \N         \N         \N          \N
# 1       \N       \N       \N       \N         \N         \N          \N
# 2       \N       \N       \N       \N         \N         \N          \N
# 3       \N       \N       \N       \N         \N         \N          \N
# 4       \N       \N       \N       \N         \N         \N          \N
#
#   sprint_time driverRef driver_num driver_code forename   surname         dob  \
# 0          \N  hamilton         44         HAM    Lewis  Hamilton  1985-01-07
# 1          \N  hamilton         44         HAM    Lewis  Hamilton  1985-01-07
# 2          \N  hamilton         44         HAM    Lewis  Hamilton  1985-01-07
# 3          \N  hamilton         44         HAM    Lewis  Hamilton  1985-01-07
# 4          \N  hamilton         44         HAM    Lewis  Hamilton  1985-01-07
#
#   nationality                                        url_y  driverStandingsId  \
# 0     British  http://en.wikipedia.org/wiki/Lewis_Hamilton                  1
# 1     British  http://en.wikipedia.org/wiki/Lewis_Hamilton                  9
# 2     British  http://en.wikipedia.org/wiki/Lewis_Hamilton                 27
# 3     British  http://en.wikipedia.org/wiki/Lewis_Hamilton                 48
# 4     British  http://en.wikipedia.org/wiki/Lewis_Hamilton                 69
#
#    raceId_y  points_y  position positionText_y  wins constructorRef  company  \
# 0        18      10.0         1              1     1        mclaren  McLaren
# 1        19      14.0         1              1     1        mclaren  McLaren
# 2        20      14.0         3              3     1        mclaren  McLaren
# 3        21      20.0         2              2     1        mclaren  McLaren
# 4        22      28.0         3              3     1        mclaren  McLaren
#
#   nationality_y                                   url    status
# 0       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 1       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 2       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 3       British  http://en.wikipedia.org/wiki/McLaren  Finished
# 4       British  http://en.wikipedia.org/wiki/McLaren  Finished

# %%
#drop unwanted columns 
df = df.drop(columns=['url_y', 'url_x', 'position_x', 'fastestLapTime', 'positionText_x', 'time_x', 
                      'driverRef', 'constructorRef', 'nationality_y', 'positionText_y', 'raceId_y', 'points_y'])

# %%
#changing the names of variables 
col_name = {'number_x':'number','milliseconds':'timetaken_in_millisec','fastestLapSpeed':'max_speed',
 'name_x':'grand_prix','number_y':'driver_num','code':'driver_code','nationality_x':'nationality','name_y':'company',
 'raceId_x':'racerId','points_x':'points','position_y':'position'}

df.rename(columns=col_name,inplace=True)
df.head()
# Out:
#    resultId  racerId  driverId  constructorId number  grid  positionOrder  \
# 0         1       18         1              1     22     1              1
# 1         1       18         1              1     22     1              1
# 2         1       18         1              1     22     1              1
# 3         1       18         1              1     22     1              1
# 4         1       18         1              1     22     1              1
#
#    points  laps timetaken_in_millisec fastestLap rank max_speed  statusId  \
# 0    10.0    58               5690616         39    2   218.300         1
# 1    10.0    58               5690616         39    2   218.300         1
# 2    10.0    58               5690616         39    2   218.300         1
# 3    10.0    58               5690616         39    2   218.300         1
# 4    10.0    58               5690616         39    2   218.300         1
#
#    year  round  circuitId             grand_prix        date    time_y  \
# 0  2008      1          1  Australian Grand Prix  2008-03-16  04:30:00
# 1  2008      1          1  Australian Grand Prix  2008-03-16  04:30:00
# 2  2008      1          1  Australian Grand Prix  2008-03-16  04:30:00
# 3  2008      1          1  Australian Grand Prix  2008-03-16  04:30:00
# 4  2008      1          1  Australian Grand Prix  2008-03-16  04:30:00
#
#   fp1_date fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# 0       \N       \N       \N       \N       \N       \N         \N         \N
# 1       \N       \N       \N       \N       \N       \N         \N         \N
# 2       \N       \N       \N       \N       \N       \N         \N         \N
# 3       \N       \N       \N       \N       \N       \N         \N         \N
# 4       \N       \N       \N       \N       \N       \N         \N         \N
#
#   sprint_date sprint_time driver_num driver_code forename   surname  \
# 0          \N          \N         44         HAM    Lewis  Hamilton
# 1          \N          \N         44         HAM    Lewis  Hamilton
# 2          \N          \N         44         HAM    Lewis  Hamilton
# 3          \N          \N         44         HAM    Lewis  Hamilton
# 4          \N          \N         44         HAM    Lewis  Hamilton
#
#           dob nationality  driverStandingsId  position  wins  company  \
# 0  1985-01-07     British                  1         1     1  McLaren
# 1  1985-01-07     British                  9         1     1  McLaren
# 2  1985-01-07     British                 27         3     1  McLaren
# 3  1985-01-07     British                 48         2     1  McLaren
# 4  1985-01-07     British                 69         3     1  McLaren
#
#                                     url    status
# 0  http://en.wikipedia.org/wiki/McLaren  Finished
# 1  http://en.wikipedia.org/wiki/McLaren  Finished
# 2  http://en.wikipedia.org/wiki/McLaren  Finished
# 3  http://en.wikipedia.org/wiki/McLaren  Finished
# 4  http://en.wikipedia.org/wiki/McLaren  Finished

# %%
#more variables to drop 
df = df.drop(columns=['year','round','circuitId','grand_prix','date','time_y',
                      'fp1_date','fp1_time','fp2_time','fp2_date','fp3_date','fp3_time',
                      'quali_date','quali_time','sprint_date','sprint_time','url'])

# %%
# Adding two column (forename,surname) to create a single column called driver_name

df['driver_name'] = df['forename']+' '+df['surname']

#dropping surname and forename
df = df.drop(columns=['forename','surname'])

# %%
df
# Out:
#          resultId  racerId  driverId  constructorId number  grid  \
# 0               1       18         1              1     22     1
# 1               1       18         1              1     22     1
# 2               1       18         1              1     22     1
# 3               1       18         1              1     22     1
# 4               1       18         1              1     22     1
# ...           ...      ...       ...            ...    ...   ...
# 3537622     26085     1110       857              1     81     5
# 3537623     26085     1110       857              1     81     5
# 3537624     26085     1110       857              1     81     5
# 3537625     26085     1110       857              1     81     5
# 3537626     26085     1110       857              1     81     5
#
#          positionOrder  points  laps timetaken_in_millisec fastestLap rank  \
# 0                    1    10.0    58               5690616         39    2
# 1                    1    10.0    58               5690616         39    2
# 2                    1    10.0    58               5690616         39    2
# 3                    1    10.0    58               5690616         39    2
# 4                    1    10.0    58               5690616         39    2
# ...                ...     ...   ...                   ...        ...  ...
# 3537622             20     0.0     0                    \N         \N    0
# 3537623             20     0.0     0                    \N         \N    0
# 3537624             20     0.0     0                    \N         \N    0
# 3537625             20     0.0     0                    \N         \N    0
# 3537626             20     0.0     0                    \N         \N    0
#
#         max_speed  statusId driver_num driver_code         dob nationality  \
# 0         218.300         1         44         HAM  1985-01-07     British
# 1         218.300         1         44         HAM  1985-01-07     British
# 2         218.300         1         44         HAM  1985-01-07     British
# 3         218.300         1         44         HAM  1985-01-07     British
# 4         218.300         1         44         HAM  1985-01-07     British
# ...           ...       ...        ...         ...         ...         ...
# 3537622        \N       130         81         PIA  2001-04-06  Australian
# 3537623        \N       130         81         PIA  2001-04-06  Australian
# 3537624        \N       130         81         PIA  2001-04-06  Australian
# 3537625        \N       130         81         PIA  2001-04-06  Australian
# 3537626        \N       130         81         PIA  2001-04-06  Australian
#
#          driverStandingsId  position  wins  company            status  \
# 0                        1         1     1  McLaren          Finished
# 1                        9         1     1  McLaren          Finished
# 2                       27         3     1  McLaren          Finished
# 3                       48         2     1  McLaren          Finished
# 4                       69         3     1  McLaren          Finished
# ...                    ...       ...   ...      ...               ...
# 3537622              72085        14     0  McLaren  Collision damage
# 3537623              72125        14     0  McLaren  Collision damage
# 3537624              72145        11     0  McLaren  Collision damage
# 3537625              72165        11     0  McLaren  Collision damage
# 3537626              72186        11     0  McLaren  Collision damage
#
#             driver_name
# 0        Lewis Hamilton
# 1        Lewis Hamilton
# 2        Lewis Hamilton
# 3        Lewis Hamilton
# 4        Lewis Hamilton
# ...                 ...
# 3537622   Oscar Piastri
# 3537623   Oscar Piastri
# 3537624   Oscar Piastri
# 3537625   Oscar Piastri
# 3537626   Oscar Piastri
#
# [3537627 rows x 24 columns]

# %%
#convert dob into age 
from datetime import datetime
df['dob'] = pd.to_datetime(df['dob'])

# creating driver's age as new column
dates = datetime.today()-df['dob']
age = dates.dt.days/365

df['age'] = round(age)

df = df.drop(columns=['driver_num','dob','statusId'])

# %%
df
# Out:
#          resultId  racerId  driverId  constructorId number  grid  \
# 0               1       18         1              1     22     1
# 1               1       18         1              1     22     1
# 2               1       18         1              1     22     1
# 3               1       18         1              1     22     1
# 4               1       18         1              1     22     1
# ...           ...      ...       ...            ...    ...   ...
# 3537622     26085     1110       857              1     81     5
# 3537623     26085     1110       857              1     81     5
# 3537624     26085     1110       857              1     81     5
# 3537625     26085     1110       857              1     81     5
# 3537626     26085     1110       857              1     81     5
#
#          positionOrder  points  laps timetaken_in_millisec fastestLap rank  \
# 0                    1    10.0    58               5690616         39    2
# 1                    1    10.0    58               5690616         39    2
# 2                    1    10.0    58               5690616         39    2
# 3                    1    10.0    58               5690616         39    2
# 4                    1    10.0    58               5690616         39    2
# ...                ...     ...   ...                   ...        ...  ...
# 3537622             20     0.0     0                    \N         \N    0
# 3537623             20     0.0     0                    \N         \N    0
# 3537624             20     0.0     0                    \N         \N    0
# 3537625             20     0.0     0                    \N         \N    0
# 3537626             20     0.0     0                    \N         \N    0
#
#         max_speed driver_code nationality  driverStandingsId  position  wins  \
# 0         218.300         HAM     British                  1         1     1
# 1         218.300         HAM     British                  9         1     1
# 2         218.300         HAM     British                 27         3     1
# 3         218.300         HAM     British                 48         2     1
# 4         218.300         HAM     British                 69         3     1
# ...           ...         ...         ...                ...       ...   ...
# 3537622        \N         PIA  Australian              72085        14     0
# 3537623        \N         PIA  Australian              72125        14     0
# 3537624        \N         PIA  Australian              72145        11     0
# 3537625        \N         PIA  Australian              72165        11     0
# 3537626        \N         PIA  Australian              72186        11     0
#
#          company            status     driver_name   age
# 0        McLaren          Finished  Lewis Hamilton  39.0
# 1        McLaren          Finished  Lewis Hamilton  39.0
# 2        McLaren          Finished  Lewis Hamilton  39.0
# 3        McLaren          Finished  Lewis Hamilton  39.0
# 4        McLaren          Finished  Lewis Hamilton  39.0
# ...          ...               ...             ...   ...
# 3537622  McLaren  Collision damage   Oscar Piastri  23.0
# 3537623  McLaren  Collision damage   Oscar Piastri  23.0
# 3537624  McLaren  Collision damage   Oscar Piastri  23.0
# 3537625  McLaren  Collision damage   Oscar Piastri  23.0
# 3537626  McLaren  Collision damage   Oscar Piastri  23.0
#
# [3537627 rows x 22 columns]
